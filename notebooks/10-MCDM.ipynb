# %%
import math
import itertools
import pandas
import numpy
from scipy.spatial import distance
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr

# %%
pandas.set_option('display.max_rows', None)

# %%
enum = { "beginner": 0, "intermediate": 1, "advanced": 2 }
inverse_enum = { 0: "beginner", 1: "intermediate", 2: "advanced" }
r = itertools.combinations_with_replacement([
    enum["beginner"],
    enum["intermediate"],
    enum["advanced"],
], 2)
r = list(r)

# %%
r
# Out:
# [(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2), (2, 0), (2, 1), (2, 2)]

# %%
x = [enum["beginner"],
    enum["intermediate"],
    enum["advanced"]]


r = [p for p in itertools.product(x, repeat=2)]

r = list(r)

# %%
r = [
    (4,8,5,6,7,1),
    (3,8,8,5,1,1),
    (3,6,8,7,1,8),
    (4,1,10,6,1,8),
    (9,5,3,6,5,1),
    (4,10,10,7,8,8),
    (3,10,6,7,1,1),
    (3,7,6,8,5,1),
    (3,10,8,8,6,5)
]

# %%
def format_result(i, j, sim, idx = ""):
    return {
        f"i{idx}": i,
        f"j{idx}": j,
#        f"Word{idx}": inverse_enum[i[2]],
        f"Similaridade{idx}": sim
    }

# %% [markdown]
# ## Continuous Saturated Merit

# %% [markdown]
# $$S_{ij} = \dfrac{\sum_{k = 0}^{N-1} \frac{r_{ik} - r_{jk}}{r_{k, max}} \cdot (\frac{r_{jk}}{r_{k, max}} + 1) \cdot c_{ijk}}
#            {\sum_{k = 0}^{N-1} {\frac{r_{jk}}{r_{k, max}} + 1}} + 1$$
#
# $$S_{ij} \in \mathclose[0,2\mathopen]$$

# %% [markdown]
# $$ c_{ijk} = \begin{cases} 1, & \mbox{if } r_{ik} < r_{jk} \\ c_{k}, & \mbox{if } r_{ik} \geq r_{jk} \end{cases} $$

# %% [markdown]
# $$ 0 \leq c_k \leq 1 $$
# $$ c_{k,min} = 0; c_{k,max} = 1 $$

# %% [markdown]
# $$ X =  \text{rank classes}  = \{ \text{"beginner"}, \text{"intermediate"}, \text{"advanced"} \} $$
# $$ r_{ik} = X^{-1}(x_{ik}) $$
# $$ X^{-1}(\text{"beginner"}) = 0, X^{-1}(\text{"intermediate"}) = 1 \text{ and } X^{-1}(\text{"advanced"}) = 2 $$

# %%
def exponential_sim_match(i, j, C = [1]*6, idx = ""):
    numerator = 0
    denominator = 0
    
    for _i, _j, _c in list(zip(i, j, C)):
        _numerator = ((_i/10) - (_j/10))*((_j/10) +1)
        
        if _i > _j:
            numerator += _numerator*_c
        else:
            numerator += _numerator
        
        denominator += ((_j/10) + 1)        
        
    return format_result(i, j, '%f' % (numerator/denominator), idx)

# %%
[exponential_sim_match([1, 2], [2, 0]), exponential_sim_match([2, 1], [2, 0])]
# Out:
# [{'i': [1, 2], 'j': [2, 0], 'Similaridade': '-0.166667'},
#  {'i': [2, 1], 'j': [2, 0], 'Similaridade': '0.083333'}]

# %%
[
    exponential_sim_match([0, 2], [2, 0]),
    exponential_sim_match([0, 2], [2, 1]),
    exponential_sim_match([0, 2], [2, 2])
]
# Out:
# [{'i': [0, 2], 'j': [2, 0], 'Similaridade': '-0.333333'},
#  {'i': [0, 2], 'j': [2, 1], 'Similaridade': '-0.357143'},
#  {'i': [0, 2], 'j': [2, 2], 'Similaridade': '-0.500000'}]

# %%
[
    exponential_sim_match([1, 2], [2, 0]),
    exponential_sim_match([1, 2], [2, 1]),
    exponential_sim_match([1, 2], [2, 2])
]
# Out:
# [{'i': [1, 2], 'j': [2, 0], 'Similaridade': '0.000000'},
#  {'i': [1, 2], 'j': [2, 1], 'Similaridade': '-0.071429'},
#  {'i': [1, 2], 'j': [2, 2], 'Similaridade': '-0.250000'}]

# %%
def cosine_sim_match(i, j, idx=""):
    return format_result(i, j, '%f' % (cosine_similarity([i], [j])), idx)

# %%
def manhattan_sim_match(i, j, idx=""):
    sim = 1 / (1 + distance.minkowski(i, j, 1))
    return format_result(i, j, '%f' % sim, idx)

# %%
def euclidian_sim_match(i, j, idx=""):
    sim = 1 / (1 + distance.minkowski(i, j, 2))
    return format_result(i, j, '%f' % sim, idx)

# %%
def pearson_sim_match(i, j, idx=""):
    sim, _ = pearsonr(i, j)
    return format_result(i, j, '%f' % sim, idx)

# %% [markdown]
# # Comparing with other measures

# %% [markdown]
# ## Cosine

# %%
list(map(lambda x: list(map(lambda i: cosine_sim_match(i, x), r)), r))

# %% [markdown]
# ## Manhattan

# %%
list(map(lambda x: list(map(lambda i: manhattan_sim_match(i, x), r)), r))

# %% [markdown]
# ## Euclidian

# %%
list(map(lambda x: list(map(lambda i: euclidian_sim_match(i, x), r)), r))

# %% [markdown]
# ## Pearson

# %%
list(map(lambda x: list(map(lambda i: pearson_sim_match(i, x), r)), r))

# %% [markdown]
# ## Our measure

# %%
#a = list(map(lambda x: list(map(lambda i: exponential_sim_match(i, x), r)), r))
i = 1
for _r in r:
    print(str(i) + str(exponential_sim_match(_r, [0, 0, 0, 0, 0, 0])))
    i+=1
# Out:
# 1{'i': (4, 8, 5, 6, 7, 1), 'j': [0, 0, 0, 0, 0, 0], 'Similaridade': '0.516667'}
# 2{'i': (3, 8, 8, 5, 1, 1), 'j': [0, 0, 0, 0, 0, 0], 'Similaridade': '0.433333'}
# 3{'i': (3, 6, 8, 7, 1, 8), 'j': [0, 0, 0, 0, 0, 0], 'Similaridade': '0.550000'}
# 4{'i': (4, 1, 10, 6, 1, 8), 'j': [0, 0, 0, 0, 0, 0], 'Similaridade': '0.500000'}
# 5{'i': (9, 5, 3, 6, 5, 1), 'j': [0, 0, 0, 0, 0, 0], 'Similaridade': '0.483333'}
# 6{'i': (4, 10, 10, 7, 8, 8), 'j': [0, 0, 0, 0, 0, 0], 'Similaridade': '0.783333'}
# 7{'i': (3, 10, 6, 7, 1, 1), 'j': [0, 0, 0, 0, 0, 0], 'Similaridade': '0.466667'}
# 8{'i': (3, 7, 6, 8, 5, 1), 'j': [0, 0, 0, 0, 0, 0], 'Similaridade': '0.500000'}
# 9{'i': (3, 10, 8, 8, 6, 5), 'j': [0, 0, 0, 0, 0, 0], 'Similaridade': '0.666667'}

# %%
a
# Out:
# [[{'i': (4, 8, 5, 6, 7, 1),
#    'j': (4, 8, 5, 6, 7, 1),
#    'Similaridade': '0.000000'},
#   {'i': (3, 8, 8, 5, 1, 1),
#    'j': (4, 8, 5, 6, 7, 1),
#    'Similaridade': '-0.095604'},
#   {'i': (3, 6, 8, 7, 1, 8),
#    'j': (4, 8, 5, 6, 7, 1),
#    'Similaridade': '-0.015385'},
#   {'i': (4, 1, 10, 6, 1, 8),
#    'j': (4, 8, 5, 6, 7, 1),
#    'Similaridade': '-0.083516'},
#   {'i': (9, 5, 3, 6, 5, 1),
#    'j': (4, 8, 5, 6, 7, 1),
#    'Similaridade': '-0.052747'},
#   {'i': (4, 10, 10, 7, 8, 8),
#    'j': (4, 8, 5, 6, 7, 1),
#    'Similaridade': '0.242857'},
#   {'i': (3, 10, 6, 7, 1, 1),
#    'j': (4, 8, 5, 6, 7, 1),
#    'Similaridade': '-0.053846'},
#   {'i': (3, 7, 6, 8, 5, 1),
#    'j': (4, 8, 5, 6, 7, 1),
#    'Similaridade': '-0.020879'},
#   {'i': (3, 10, 8, 8, 6, 5),
#    'j': (4, 8, 5, 6, 7, 1),
#    'Similaridade': '0.138462'}],
#  [{'i': (4, 8, 5, 6, 7, 1),
#    'j': (3, 8, 8, 5, 1, 1),
#    'Similaridade': '0.046512'},
#   {'i': (3, 8, 8, 5, 1, 1),
#    'j': (3, 8, 8, 5, 1, 1),
#    'Similaridade': '0.000000'},
#   {'i': (3, 6, 8, 7, 1, 8),
#    'j': (3, 8, 8, 5, 1, 1),
#    'Similaridade': '0.082558'},
#   {'i': (4, 1, 10, 6, 1, 8),
#    'j': (3, 8, 8, 5, 1, 1),
#    'Similaridade': '0.017442'},
#   {'i': (9, 5, 3, 6, 5, 1),
#    'j': (3, 8, 8, 5, 1, 1),
#    'Similaridade': '-0.008140'},
#   {'i': (4, 10, 10, 7, 8, 8),
#    'j': (3, 8, 8, 5, 1, 1),
#    'Similaridade': '0.312791'},
#   {'i': (3, 10, 6, 7, 1, 1),
#    'j': (3, 8, 8, 5, 1, 1),
#    'Similaridade': '0.034884'},
#   {'i': (3, 7, 6, 8, 5, 1),
#    'j': (3, 8, 8, 5, 1, 1),
#    'Similaridade': '0.040698'},
#   {'i': (3, 10, 8, 8, 6, 5),
#    'j': (3, 8, 8, 5, 1, 1),
#    'Similaridade': '0.209302'}],
#  [{'i': (4, 8, 5, 6, 7, 1),
#    'j': (3, 6, 8, 7, 1, 8),
#    'Similaridade': '-0.092473'},
#   {'i': (3, 8, 8, 5, 1, 1),
#    'j': (3, 6, 8, 7, 1, 8),
#    'Similaridade': '-0.137634'},
#   {'i': (3, 6, 8, 7, 1, 8),
#    'j': (3, 6, 8, 7, 1, 8),
#    'Similaridade': '0.000000'},
#   {'i': (4, 1, 10, 6, 1, 8),
#    'j': (3, 6, 8, 7, 1, 8),
#    'Similaridade': '-0.051613'},
#   {'i': (9, 5, 3, 6, 5, 1),
#    'j': (3, 6, 8, 7, 1, 8),
#    'Similaridade': '-0.136559'},
#   {'i': (4, 10, 10, 7, 8, 8),
#    'j': (3, 6, 8, 7, 1, 8),
#    'Similaridade': '0.204301'},
#   {'i': (3, 10, 6, 7, 1, 1),
#    'j': (3, 6, 8, 7, 1, 8),
#    'Similaridade': '-0.105376'},
#   {'i': (3, 7, 6, 8, 5, 1),
#    'j': (3, 6, 8, 7, 1, 8),
#    'Similaridade': '-0.091398'},
#   {'i': (3, 10, 8, 8, 6, 5),
#    'j': (3, 6, 8, 7, 1, 8),
#    'Similaridade': '0.088172'}],
#  [{'i': (4, 8, 5, 6, 7, 1),
#    'j': (4, 1, 10, 6, 1, 8),
#    'Similaridade': '-0.092222'},
#   {'i': (3, 8, 8, 5, 1, 1),
#    'j': (4, 1, 10, 6, 1, 8),
#    'Similaridade': '-0.132222'},
#   {'i': (3, 6, 8, 7, 1, 8),
#    'j': (4, 1, 10, 6, 1, 8),
#    'Similaridade': '0.018889'},
#   {'i': (4, 1, 10, 6, 1, 8),
#    'j': (4, 1, 10, 6, 1, 8),
#    'Similaridade': '0.000000'},
#   {'i': (9, 5, 3, 6, 5, 1),
#    'j': (4, 1, 10, 6, 1, 8),
#    'Similaridade': '-0.120000'},
#   {'i': (4, 10, 10, 7, 8, 8),
#    'j': (4, 1, 10, 6, 1, 8),
#    'Similaridade': '0.213333'},
#   {'i': (3, 10, 6, 7, 1, 1),
#    'j': (4, 1, 10, 6, 1, 8),
#    'Similaridade': '-0.116667'},
#   {'i': (3, 7, 6, 8, 5, 1),
#    'j': (4, 1, 10, 6, 1, 8),
#    'Similaridade': '-0.086667'},
#   {'i': (3, 10, 8, 8, 6, 5),
#    'j': (4, 1, 10, 6, 1, 8),
#    'Similaridade': '0.086667'}],
#  [{'i': (4, 8, 5, 6, 7, 1),
#    'j': (9, 5, 3, 6, 5, 1),
#    'Similaridade': '0.006742'},
#   {'i': (3, 8, 8, 5, 1, 1),
#    'j': (9, 5, 3, 6, 5, 1),
#    'Similaridade': '-0.089888'},
#   {'i': (3, 6, 8, 7, 1, 8),
#    'j': (9, 5, 3, 6, 5, 1),
#    'Similaridade': '-0.001124'},
#   {'i': (4, 1, 10, 6, 1, 8),
#    'j': (9, 5, 3, 6, 5, 1),
#    'Similaridade': '-0.052809'},
#   {'i': (9, 5, 3, 6, 5, 1),
#    'j': (9, 5, 3, 6, 5, 1),
#    'Similaridade': '0.000000'},
#   {'i': (4, 10, 10, 7, 8, 8),
#    'j': (9, 5, 3, 6, 5, 1),
#    'Similaridade': '0.234831'},
#   {'i': (3, 10, 6, 7, 1, 1),
#    'j': (9, 5, 3, 6, 5, 1),
#    'Similaridade': '-0.049438'},
#   {'i': (3, 7, 6, 8, 5, 1),
#    'j': (9, 5, 3, 6, 5, 1),
#    'Similaridade': '-0.014607'},
#   {'i': (3, 10, 8, 8, 6, 5),
#    'j': (9, 5, 3, 6, 5, 1),
#    'Similaridade': '0.131461'}],
#  [{'i': (4, 8, 5, 6, 7, 1),
#    'j': (4, 10, 10, 7, 8, 8),
#    'Similaridade': '-0.281308'},
#   {'i': (3, 8, 8, 5, 1, 1),
#    'j': (4, 10, 10, 7, 8, 8),
#    'Similaridade': '-0.355140'},
#   {'i': (3, 6, 8, 7, 1, 8),
#    'j': (4, 10, 10, 7, 8, 8),
#    'Similaridade': '-0.242991'},
#   {'i': (4, 1, 10, 6, 1, 8),
#    'j': (4, 10, 10, 7, 8, 8),
#    'Similaridade': '-0.301869'},
#   {'i': (9, 5, 3, 6, 5, 1),
#    'j': (4, 10, 10, 7, 8, 8),
#    'Similaridade': '-0.342991'},
#   {'i': (4, 10, 10, 7, 8, 8),
#    'j': (4, 10, 10, 7, 8, 8),
#    'Similaridade': '0.000000'},
#   {'i': (3, 10, 6, 7, 1, 1),
#    'j': (4, 10, 10, 7, 8, 8),
#    'Similaridade': '-0.323364'},
#   {'i': (3, 7, 6, 8, 5, 1),
#    'j': (4, 10, 10, 7, 8, 8),
#    'Similaridade': '-0.296262'},
#   {'i': (3, 10, 8, 8, 6, 5),
#    'j': (4, 10, 10, 7, 8, 8),
#    'Similaridade': '-0.118692'}],
#  [{'i': (4, 8, 5, 6, 7, 1),
#    'j': (3, 10, 6, 7, 1, 1),
#    'Similaridade': '0.006818'},
#   {'i': (3, 8, 8, 5, 1, 1),
#    'j': (3, 10, 6, 7, 1, 1),
#    'Similaridade': '-0.047727'},
#   {'i': (3, 6, 8, 7, 1, 8),
#    'j': (3, 10, 6, 7, 1, 1),
#    'Similaridade': '0.032955'},
#   {'i': (4, 1, 10, 6, 1, 8),
#    'j': (3, 10, 6, 7, 1, 1),
#    'Similaridade': '-0.048864'},
#   {'i': (9, 5, 3, 6, 5, 1),
#    'j': (3, 10, 6, 7, 1, 1),
#    'Similaridade': '-0.048864'},
#   {'i': (4, 10, 10, 7, 8, 8),
#    'j': (3, 10, 6, 7, 1, 1),
#    'Similaridade': '0.262500'},
#   {'i': (3, 10, 6, 7, 1, 1),
#    'j': (3, 10, 6, 7, 1, 1),
#    'Similaridade': '0.000000'},
#   {'i': (3, 7, 6, 8, 5, 1),
#    'j': (3, 10, 6, 7, 1, 1),
#    'Similaridade': '0.001136'},
#   {'i': (3, 10, 8, 8, 6, 5),
#    'j': (3, 10, 6, 7, 1, 1),
#    'Similaridade': '0.168182'}],
#  [{'i': (4, 8, 5, 6, 7, 1),
#    'j': (3, 7, 6, 8, 5, 1),
#    'Similaridade': '0.008889'},
#   {'i': (3, 8, 8, 5, 1, 1),
#    'j': (3, 7, 6, 8, 5, 1),
#    'Similaridade': '-0.072222'},
#   {'i': (3, 6, 8, 7, 1, 8),
#    'j': (3, 7, 6, 8, 5, 1),
#    'Similaridade': '0.015556'},
#   {'i': (4, 1, 10, 6, 1, 8),
#    'j': (3, 7, 6, 8, 5, 1),
#    'Similaridade': '-0.048889'},
#   {'i': (9, 5, 3, 6, 5, 1),
#    'j': (3, 7, 6, 8, 5, 1),
#    'Similaridade': '-0.044444'},
#   {'i': (4, 10, 10, 7, 8, 8),
#    'j': (3, 7, 6, 8, 5, 1),
#    'Similaridade': '0.257778'},
#   {'i': (3, 10, 6, 7, 1, 1),
#    'j': (3, 7, 6, 8, 5, 1),
#    'Similaridade': '-0.030000'},
#   {'i': (3, 7, 6, 8, 5, 1),
#    'j': (3, 7, 6, 8, 5, 1),
#    'Similaridade': '0.000000'},
#   {'i': (3, 10, 8, 8, 6, 5),
#    'j': (3, 7, 6, 8, 5, 1),
#    'Similaridade': '0.157778'}],
#  [{'i': (4, 8, 5, 6, 7, 1),
#    'j': (3, 10, 8, 8, 6, 5),
#    'Similaridade': '-0.161000'},
#   {'i': (3, 8, 8, 5, 1, 1),
#    'j': (3, 10, 8, 8, 6, 5),
#    'Similaridade': '-0.234000'},
#   {'i': (3, 6, 8, 7, 1, 8),
#    'j': (3, 10, 8, 8, 6, 5),
#    'Similaridade': '-0.133000'},
#   {'i': (4, 1, 10, 6, 1, 8),
#    'j': (3, 10, 8, 8, 6, 5),
#    'Similaridade': '-0.202000'},
#   {'i': (9, 5, 3, 6, 5, 1),
#    'j': (3, 10, 8, 8, 6, 5),
#    'Similaridade': '-0.224000'},
#   {'i': (4, 10, 10, 7, 8, 8),
#    'j': (3, 10, 8, 8, 6, 5),
#    'Similaridade': '0.108000'},
#   {'i': (3, 10, 6, 7, 1, 1),
#    'j': (3, 10, 8, 8, 6, 5),
#    'Similaridade': '-0.194000'},
#   {'i': (3, 7, 6, 8, 5, 1),
#    'j': (3, 10, 8, 8, 6, 5),
#    'Similaridade': '-0.172000'},
#   {'i': (3, 10, 8, 8, 6, 5),
#    'j': (3, 10, 8, 8, 6, 5),
#    'Similaridade': '0.000000'}]]

# %%
com_can = []
for company in a:
    _r = []
    for candidate in company:
        _r.append(candidate['Similaridade'])
    com_can.append(_r)
    
t = numpy.transpose(com_can)
for candidate in t:
    print(' & '.join(map(lambda o: str(Decimal(str(o)).normalize()), candidate)) + " \\\\")
# Out:
# 0 & -0.3 & -0.666667 & -0.3 & -0.5 & -0.785714 & -0.666667 & -0.785714 & -1 \\
# 0 & 0 & -0.333333 & -0.3 & -0.25 & -0.5 & -0.666667 & -0.571429 & -0.75 \\
# 0 & 0 & 0 & -0.3 & -0.25 & -0.214286 & -0.666667 & -0.571429 & -0.5 \\
# 0 & -0.3 & -0.666667 & 0 & -0.25 & -0.571429 & -0.333333 & -0.5 & -0.75 \\
# 0 & 0 & -0.333333 & 0 & 0 & -0.285714 & -0.333333 & -0.285714 & -0.5 \\
# 0 & 0 & 0 & 0 & 0 & 0 & -0.333333 & -0.285714 & -0.25 \\
# 0 & -0.3 & -0.666667 & 0 & -0.25 & -0.571429 & 0 & -0.214286 & -0.5 \\
# 0 & 0 & -0.333333 & 0 & 0 & -0.285714 & 0 & 0 & -0.25 \\
# 0 & 0 & 0 & 0 & 0 & 0 & 0 & 0 & 0 \\

# %%
from decimal import Decimal

# %%
[exponential_sim_match(j=[0,0], i= [2,2], C=[1, 1]),
exponential_sim_match(j = [2,0], i= [1,1], C=[1, 0]),
exponential_sim_match(j = [2,0], i= [1,2], C=[1, 0])
                     ]
# Out:
# [{'i': [2, 2], 'j': [0, 0], 'Similaridade': '1.000000'},
#  {'i': [1, 1], 'j': [2, 0], 'Similaridade': '-0.500000'},
#  {'i': [1, 2], 'j': [2, 0], 'Similaridade': '-0.500000'}]

# %% [markdown]
# ## Análise
#
# ### Mérito Continuo
#
# - Usuário tem a opção de valorizar os conhecimentos a mais de forma gradual
# - Usuário deve ter em mente que se a maioria dos atributos não valorizar o conhecimento a mais, as similaridades serão muito similares, indepedente do nível de conhecimento
# - O mérito da cada variável é independente
# - Valoriza os conhecimentos de forma quadrádica (ex, doutorado >>> mestrado >> bacharel > técnico)
#
#
# ### Mérito Binário
#
# - Não faz sentido permitir méritos contínuos com a estratégia de valorizar os conhecimentos a mais de todos os atributos quando mais do que a metade dos méritos for 0
#     - Todos os valores contínuos dos méritos iriam se tornar 1? Os valores diferentes de 0 iriam se manter?
# - Usuário deve ter em mente que a valorização dos conhecimentos a mais ocorrerá em todos os atributos se houver mais do que a metade dos atributos de zeros como méritos
#
# ---------------------
#
# Aplicações
#
# - o valor padrão de mérito pode ser 1, tanto para contínuo e binário, sempre valorizar os conhecimentos a mais. Se o usuário quiser um valor diferente para certo atributo, ele que mude
# - para vários atributos, definir um valor de mérito contínuo será uma tarefa tediosa, portanto, a melhor opção talvez seria a opção dos méritos binários
# - para poucos atributos, não é trabalhoso definir o mérito para cada um, portanto, a melhor opção pode ser a dos méritos contínuos

# %%
j_s1 = [2, 2]
c_s1 = [0, 0]
result = list(map(lambda i: exponential_sim_match(i, j_s1, c_s1, 1), list(r)))

j_s2 = [0, 0, 0]
c_s2 = [1, 1, 1]
result2 = list(map(lambda i: exponential_sim_match(i, j_s1, c_s2, 2), list(r)))

# %%
[
    exponential_sim_match(i = [2, 2], j = [0, 0], C = [1, 1]),
    exponential_sim_match(i = [1, 1], j = [2, 2], C = [0, 0]),
]
# Out:
# [{'Excel': 2, 'PPT': 2, 'Similaridade': '2.000000'},
#  {'Excel': 1, 'PPT': 1, 'Similaridade': '0.500000'}]

# %%
result = sorted(result, key=lambda x: x["Similaridade1"])
result2 = sorted(result2, key=lambda x: x["Similaridade2"])

# %%
for i, v in enumerate(result): result[i]['idx1'] = i
for i, v in enumerate(result): result2[i]['idx2'] = i

# %%
result1_df = pandas.DataFrame(result)
result2_df = pandas.DataFrame(result2)

print(f"Empresa1: {str(j_s1)} | c1 = {str(c_s1)} ======= Empresa2: {str(j_s2)} | c2 = {str(c_s2)} ")
pandas.concat([result1_df, result2_df], axis=1)
# Out:
# Empresa1: [2, 2, 2] | c1 = [1, 1, 0] ======= Empresa2: [0, 0, 0] | c2 = [1, 1, 1]
#       Excel1      PPT1     Word1 Similaridade1  idx1    Excel2      PPT2  \
# 0       nada      nada      nada     -0.444444     0      nada      nada
# 1       nada      nada    básico     -0.407407     1      nada      nada
# 2       nada      nada     médio     -0.296296     2      nada      nada
# 3       nada      nada  avançado     -0.296296     3      nada      nada
# 4       nada    básico      nada     -0.407407     4      nada    básico
# 5       nada    básico    básico     -0.370370     5      nada    básico
# 6       nada    básico     médio     -0.259259     6      nada    básico
# 7       nada    básico  avançado     -0.259259     7      nada    básico
# 8       nada     médio      nada     -0.296296     8      nada     médio
# 9       nada     médio    básico     -0.259259     9      nada     médio
# 10      nada     médio     médio     -0.148148    10      nada     médio
# 11      nada     médio  avançado     -0.148148    11      nada     médio
# 12      nada  avançado      nada     -0.111111    12      nada  avançado
# 13      nada  avançado    básico     -0.074074    13      nada  avançado
# 14      nada  avançado     médio      0.037037    14      nada  avançado
# 15      nada  avançado  avançado      0.037037    15      nada  avançado
# 16    básico      nada      nada     -0.407407    16    básico      nada
# 17    básico      nada    básico     -0.370370    17    básico      nada
# 18    básico      nada     médio     -0.259259    18    básico      nada
# 19    básico      nada  avançado     -0.259259    19    básico      nada
# 20    básico    básico      nada     -0.370370    20    básico    básico
# 21    básico    básico    básico     -0.333333    21    básico    básico
# 22    básico    básico     médio     -0.222222    22    básico    básico
# 23    básico    básico  avançado     -0.222222    23    básico    básico
# 24    básico     médio      nada     -0.259259    24    básico     médio
# 25    básico     médio    básico     -0.222222    25    básico     médio
# 26    básico     médio     médio     -0.111111    26    básico     médio
# 27    básico     médio  avançado     -0.111111    27    básico     médio
# 28    básico  avançado      nada     -0.074074    28    básico  avançado
# 29    básico  avançado    básico     -0.037037    29    básico  avançado
# 30    básico  avançado     médio      0.074074    30    básico  avançado
# 31    básico  avançado  avançado      0.074074    31    básico  avançado
# 32     médio      nada      nada     -0.296296    32     médio      nada
# 33     médio      nada    básico     -0.259259    33     médio      nada
# 34     médio      nada     médio     -0.148148    34     médio      nada
# 35     médio      nada  avançado     -0.148148    35     médio      nada
# 36     médio    básico      nada     -0.259259    36     médio    básico
# 37     médio    básico    básico     -0.222222    37     médio    básico
# 38     médio    básico     médio     -0.111111    38     médio    básico
# 39     médio    básico  avançado     -0.111111    39     médio    básico
# 40     médio     médio      nada     -0.148148    40     médio     médio
# 41     médio     médio    básico     -0.111111    41     médio     médio
# 42     médio     médio     médio      0.000000    42     médio     médio
# 43     médio     médio  avançado      0.000000    43     médio     médio
# 44     médio  avançado      nada      0.037037    44     médio  avançado
# 45     médio  avançado    básico      0.074074    45     médio  avançado
# 46     médio  avançado     médio      0.185185    46     médio  avançado
# 47     médio  avançado  avançado      0.185185    47     médio  avançado
# 48  avançado      nada      nada     -0.111111    48  avançado      nada
# 49  avançado      nada    básico     -0.074074    49  avançado      nada
# 50  avançado      nada     médio      0.037037    50  avançado      nada
# 51  avançado      nada  avançado      0.037037    51  avançado      nada
# 52  avançado    básico      nada     -0.074074    52  avançado    básico
# 53  avançado    básico    básico     -0.037037    53  avançado    básico
# 54  avançado    básico     médio      0.074074    54  avançado    básico
# 55  avançado    básico  avançado      0.074074    55  avançado    básico
# 56  avançado     médio      nada      0.037037    56  avançado     médio
# 57  avançado     médio    básico      0.074074    57  avançado     médio
# 58  avançado     médio     médio      0.185185    58  avançado     médio
# 59  avançado     médio  avançado      0.185185    59  avançado     médio
# 60  avançado  avançado      nada      0.222222    60  avançado  avançado
# 61  avançado  avançado    básico      0.259259    61  avançado  avançado
# 62  avançado  avançado     médio      0.370370    62  avançado  avançado
# 63  avançado  avançado  avançado      0.370370    63  avançado  avançado
#
#        Word2 Similaridade2  idx2
# 0       nada     -0.444444     0
# 1     básico     -0.407407     1
# 2      médio     -0.296296     2
# 3   avançado     -0.111111     3
# 4       nada     -0.407407     4
# 5     básico     -0.370370     5
# 6      médio     -0.259259     6
# 7   avançado     -0.074074     7
# 8       nada     -0.296296     8
# 9     básico     -0.259259     9
# 10     médio     -0.148148    10
# 11  avançado      0.037037    11
# 12      nada     -0.111111    12
# 13    básico     -0.074074    13
# 14     médio      0.037037    14
# 15  avançado      0.222222    15
# 16      nada     -0.407407    16
# 17    básico     -0.370370    17
# 18     médio     -0.259259    18
# 19  avançado     -0.074074    19
# 20      nada     -0.370370    20
# 21    básico     -0.333333    21
# 22     médio     -0.222222    22
# 23  avançado     -0.037037    23
# 24      nada     -0.259259    24
# 25    básico     -0.222222    25
# 26     médio     -0.111111    26
# 27  avançado      0.074074    27
# 28      nada     -0.074074    28
# 29    básico     -0.037037    29
# 30     médio      0.074074    30
# 31  avançado      0.259259    31
# 32      nada     -0.296296    32
# 33    básico     -0.259259    33
# 34     médio     -0.148148    34
# 35  avançado      0.037037    35
# 36      nada     -0.259259    36
# 37    básico     -0.222222    37
# 38     médio     -0.111111    38
# 39  avançado      0.074074    39
# 40      nada     -0.148148    40
# 41    básico     -0.111111    41
# 42     médio      0.000000    42
# 43  avançado      0.185185    43
# 44      nada      0.037037    44
# 45    básico      0.074074    45
# 46     médio      0.185185    46
# 47  avançado      0.370370    47
# 48      nada     -0.111111    48
# 49    básico     -0.074074    49
# 50     médio      0.037037    50
# 51  avançado      0.222222    51
# 52      nada     -0.074074    52
# 53    básico     -0.037037    53
# 54     médio      0.074074    54
# 55  avançado      0.259259    55
# 56      nada      0.037037    56
# 57    básico      0.074074    57
# 58     médio      0.185185    58
# 59  avançado      0.370370    59
# 60      nada      0.222222    60
# 61    básico      0.259259    61
# 62     médio      0.370370    62
# 63  avançado      0.555556    63
